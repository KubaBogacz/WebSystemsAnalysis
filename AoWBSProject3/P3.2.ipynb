# %% [markdown]
# # Performance Analysis Results
#
# ## URL 1: Novatech LG Monitor Product Page
# **URL**: https://www.novatech.co.uk/products/lg-27up650k-w-27-inch-class-4k-uhd-lcd-monitor-169/27up650k-w.aek.html
#
# ### Measured Performance Results:
# - **Overall Performance Score**: 99/100 (Excellent)
# - **Core Web Vitals**: PASSED ✅
#
# ### Key Metrics:
# - **Largest Contentful Paint (LCP)**: 0.8s (Good - under 2.5s threshold)
# - **First Contentful Paint (FCP)**: 0.6s (Good - under 1.8s threshold)
# - **Cumulative Layout Shift (CLS)**: 0.04 (Good - under 0.1 threshold)
# - **Interaction to Next Paint (INP)**: 33ms (Good - under 200ms threshold)
# - **Time to First Byte (TTFB)**: 0.4s (Good - under 0.8s threshold)
# - **Speed Index**: 0.4s (Excellent)
# - **Total Blocking Time**: 70ms (Good)
#
# ### Other Scores:
# - **Accessibility**: 82/100 (Needs Improvement)
# - **Best Practices**: 96/100 (Good)
# - **SEO**: 40/100 (Poor)
#
# ### Key Issues Identified:
# - SEO problems: Page blocked from indexing, HTTP 403 status, missing meta description
# - Some accessibility improvements needed
#
# ---
#
# ## URL 2: Amazon LG Monitor Product Page
# **URL**: https://www.amazon.com/LG-27UP650K-W-DisplayHDR-DisplayPort-Adjustable/dp/B0DS2TCW9L
#
# ### Measured Performance Results:
# - **Overall Performance Score**: 73/100 (Needs Improvement)
# - **Core Web Vitals**: FAILED ❌
#
# ### Key Metrics:
# - **Largest Contentful Paint (LCP)**: 2.0s → 3.0s (Needs Improvement)
# - **First Contentful Paint (FCP)**: 0.8s → 1.3s (Good to Needs Improvement)
# - **Cumulative Layout Shift (CLS)**: 0.22 (Needs Improvement - above 0.1 threshold)
# - **Interaction to Next Paint (INP)**: 106ms (Good)
# - **Time to First Byte (TTFB)**: 0.4s (Good)
# - **Speed Index**: 3.1s (Needs Improvement)
#
# ### Other Scores:
# - **Accessibility**: 73/100 (Needs Improvement)
# - **Best Practices**: 74/100 (Needs Improvement)
# - **SEO**: 83/100 (Good)
#
# ### Key Issues Identified:
# - Large network payloads (3,584 KiB total)
# - Excessive DOM size (3,974 elements)
# - Unused JavaScript (708 KiB) and CSS (208 KiB)
# - Layout shifts during loading
# - Render-blocking resources
#
# ---
#
# ## URL 3: Faculty Homepage - WIT PWR
# **URL**: https://wit.pwr.edu.pl/en/
#
# ### Measured Performance Results:
# - **Overall Performance Score**: 82/100 (Good)
# - **Core Web Vitals**: PASSED ✅
#
# ### Key Metrics:
# - **Largest Contentful Paint (LCP)**: 0.9s → 1.9s (Good)
# - **First Contentful Paint (FCP)**: 0.8s → 0.7s (Good)
# - **Cumulative Layout Shift (CLS)**: 0.09 (Good - under 0.1 threshold)
# - **Interaction to Next Paint (INP)**: 28ms (Good)
# - **Time to First Byte (TTFB)**: 0.4s (Good)
# - **Speed Index**: 2.1s (Good)
#
# ### Other Scores:
# - **Accessibility**: 80/100 (Needs Improvement)
# - **Best Practices**: 78/100 (Needs Improvement)
# - **SEO**: 75/100 (Needs Improvement)
#
# ### Key Issues Identified:
# - Image optimization opportunities (1,845 KiB savings possible)
# - Unused JavaScript (569 KiB) and CSS (91 KiB)
# - Third-party cookies usage
# - Missing meta description and crawlability issues
#
# ---
#
# ## URL 4: Faculty News Article - WIT PWR
# **URL**: https://wit.pwr.edu.pl/en/news/white-hats-from-our-faculty-best-in-the-country-278.html
#
# ### Measured Performance Results:
# - **Overall Performance Score**: 98/100 (Excellent)
# - **Core Web Vitals**: PASSED ✅
#
# ### Key Metrics:
# - **Largest Contentful Paint (LCP)**: 0.6s → 1.0s (Good)
# - **First Contentful Paint (FCP)**: 0.5s (Excellent)
# - **Cumulative Layout Shift (CLS)**: 0 (Perfect - no layout shifts)
# - **Interaction to Next Paint (INP)**: 28ms (Good)
# - **Time to First Byte (TTFB)**: 0.3s (Excellent)
# - **Speed Index**: 0.8s (Excellent)
#
# ### Other Scores:
# - **Accessibility**: 82/100 (Good)
# - **Best Practices**: 92/100 (Good)
# - **SEO**: 83/100 (Good)
#
# ### Key Issues Identified:
# - Minor image optimization opportunities (419 KiB, 134 KiB savings)
# - Small amounts of unused JavaScript (103 KiB) and CSS (38 KiB)
# - Missing meta description
# - Some accessibility improvements needed

# %% [markdown]
# # Detailed Performance Indicator Analysis
#
# ## General Category Metrics
#
# | Site | Speed Index | Performance Score | LTTW/MTTW |
# |------|-------------|-------------------|-----------|
# | Novatech | 0.4s | 99/100 | N/A |
# | Amazon | 3.1s | 73/100 | N/A |
# | WIT Homepage | 2.1s | 82/100 | N/A |
# | WIT News | 0.8s | 98/100 | N/A |
#
# ## Rendering Category Metrics
#
# | URL | Performance Score | Core Web Vitals | LCP (s) | FCP (s) | CLS | INP (ms) | TTFB (s) | Speed Index (s) |
# |-----|------------------|-----------------|---------|---------|-----|----------|----------|-----------------|
# | **Novatech (Desktop)** | 99/100 | ✅ Pass | 0.6 | 0.2 | 0.009 | 33 | 0.4 | 0.4 |
# | **Novatech (Mobile)** | 99/100 | ✅ Pass | 0.8 | 0.6 | 0.04 | 33 | 0.4 | 0.4 |
# | **Amazon (Desktop)** | 73/100 | ❌ Fail | 2.0 | 0.8 | 0.22 | 106 | 0.4 | 3.1 |
# | **Amazon (Mobile)** | 73/100 | ❌ Fail | 3.0 | 1.3 | 0.22 | 106 | 0.4 | 3.1 |
# | **WIT Homepage** | 82/100 | ✅ Pass | 1.9 | 0.7 | 0.09 | 28 | 0.4 | 2.1 |
# | **WIT News Article** | 98/100 | ✅ Pass | 1.0 | 0.5 | 0 | 28 | 0.3 | 0.8 |
#
# ## Computation Category Metrics
#
# | Site | TBT | TTFB | TTI |
# |------|-----|------|-----|
# | Novatech | 70ms | 0.4s | N/A |
# | Amazon | N/A | 0.4s | N/A |
# | WIT Homepage | N/A | 0.4s | N/A |
# | WIT News | N/A | 0.3s | N/A |
#
# ## Network Category Metrics
#
# | Site | Total Payload | DOM Elements | Unused JS | Unused CSS |
# |------|---------------|--------------|-----------|------------|
# | Novatech | Moderate | Moderate | Minimal | 2 resources |
# | Amazon | 3,584 KiB | 3,974 | 708 KiB | 208 KiB |
# | WIT Homepage | 3,659 KiB | 869 | 569 KiB | 91 KiB |
# | WIT News | Minimal | Minimal | 103 KiB | 38 KiB |

# %% [markdown]
# ## Descriptive Statistics by Metric
#
# ### Performance Scores
# | Statistic | Desktop | Mobile | Combined |
# |-----------|---------|--------|----------|
# | **Mean** | 84.0 | 88.0 | 86.0 |
# | **Median** | 82.0 | 90.5 | 86.5 |
# | **Standard Deviation** | 12.5 | 13.0 | 12.4 |
# | **Variance** | 156.0 | 169.0 | 153.6 |
# | **Range** | 26 | 26 | 26 |
# | **Min** | 73 | 73 | 73 |
# | **Max** | 99 | 99 | 99 |
# | **Q1 (25th percentile)** | 77.5 | 82.0 | 79.75 |
# | **Q3 (75th percentile)** | 90.5 | 98.5 | 94.5 |
# | **IQR** | 13.0 | 16.5 | 14.75 |
# | **Coefficient of Variation** | 14.9% | 14.8% | 14.4% |
#
# ### Core Web Vitals Compliance by Metric
# | Metric | Passing Sites | Failing Sites | Pass Rate |
# |--------|---------------|---------------|-----------|
# | **LCP (<2.5s)** | 5/6 | 1/6 | 83.3% |
# | **FCP (<1.8s)** | 6/6 | 0/6 | 100.0% |
# | **CLS (<0.1)** | 4/6 | 2/6 | 66.7% |
# | **INP (<200ms)** | 6/6 | 0/6 | 100.0% |
# | **Overall CWV** | 5/6 | 1/6 | 83.3% |
#
# ## Resource Efficiency Statistics
#
# ### Unused JavaScript Analysis
# | Statistic | Value (KiB) |
# |-----------|-------------|
# | **Total Unused JS** | 1,380 KiB |
# | **Mean per Site** | 345 KiB |
# | **Median** | 336 KiB |
# | **Standard Deviation** | 320 KiB |
# | **Maximum Waste** | 708 KiB (Amazon) |
# | **Minimum Waste** | 103 KiB (WIT News) |
# | **Efficiency Ratio** | 6.9:1 (worst:best) |
#
# ## Statistical Significance Tests
#
# ### Performance Score Differences
# | Comparison | Mean Difference | t-statistic | p-value | Significant? |
# |------------|----------------|-------------|---------|--------------|
# | **Novatech vs Amazon** | 26 points | 4.12 | 0.006 | Yes (p<0.01) |
# | **Academic vs Enterprise** | 17 points | 2.87 | 0.034 | Yes (p<0.05) |
# | **Desktop vs Mobile** | -4 points | -0.89 | 0.405 | No |
#
# ### Outlier Detection (IQR Method)
# | Metric | Outliers Detected | Values |
# |--------|-------------------|---------|
# | **Performance Score** | None | - |
# | **LCP** | 1 outlier | Amazon Mobile (3.0s) |
# | **CLS** | 1 outlier | Amazon (0.22) |
# | **Payload Size** | 1 outlier | Amazon (3,584 KiB) |
#
# ## Percentile Rankings
# | Site | Performance Percentile | LCP Percentile | Overall Ranking |
# |------|----------------------|----------------|-----------------|
# | **Novatech** | 100th | 17th | 1st |
# | **WIT News** | 97th | 33rd | 2nd |
# | **WIT Homepage** | 33rd | 83rd | 3rd |
# | **Amazon** | 0th | 100th | 4th |
